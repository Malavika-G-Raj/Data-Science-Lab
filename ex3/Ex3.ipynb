# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([1,2,6,18])
ypoints = np.array([3,10,12,20])

plt.plot(y, ypoints,color='g',marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([12,14,16,18,20,22,24])
ypoints = np.array([100,200,250,400,300,450,500])

plt.plot(y, ypoints,color='r',linestyle = 'dotted',marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
with open("test.txt") as f:
    data = f.read().strip()
    print(data.strip())
data = data.split('#')
print(data)
x = [row.split(' ')[0] for row in data]
print(x)
y = [row.split(' ')[1] for row in data]
print(y)
plt.plot(x, y,marker="o")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sample graph!')
plt.show()
# Out:
# 1 2#2 4#1 3
# ['1 2', '2 4', '1 3']
# ['1', '2', '1']
# ['2', '4', '3']

# %%
import matplotlib.pyplot as plt
x1 = [10,20,30]
y1 = [20,40,10]
plt.plot(x1, y1, label = "line 1",marker="o")
y2 = [40,10,30]
plt.plot(x1, y2, label = "line 2",marker="o")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Two or more lines on same plot with suitable legends ')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.subplots_adjust(bottom=0.020, left=0.020, top = 0.900, right=0.800)

plt.subplot(2, 1, 1)
plt.xticks(()), plt.yticks(())

plt.subplot(2, 3, 4)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 5)
plt.xticks(())
plt.yticks(())

plt.subplot(2, 3, 6)
plt.xticks(())
plt.yticks(())

plt.show()
